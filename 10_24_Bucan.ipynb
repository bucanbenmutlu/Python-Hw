# %%
a = 20
b = 20

# %%
weight_in_kilometers = float(input("Enter weight amount:"))
height_in_kilometers = float(input("Enter your height amount:"))
if

# %%
print(a == b)
# Out:
# True

# %%
x = 3
y = 4
print(x < y)
# Out:
# True

# %%
age1 = int(input("Enter an age : "))
age2 = int(input("Enter an age : "))

if age1 >= age2:
  print("age 1 is older than age 2")
else:
  print("Not acceptable condition !")
# Out:
# Enter an age : 10
# Enter an age : 10
# age 1 is older than age 2

# %%
purchase_amount = float(input("Enter your purchase amount : "))

if purchase_amount > 1000:
  topay = purchase_amount * 0.75
  print("You got a discount ! ")
  print("You need to pay : " , topay)
else:
  topay = purchase_amount
  print("You need to pay : " , topay)
# Out:
# Enter your purchase amount : 1100
# You got a discount !
# You need to pay :  825.0

# %%
speed_limit = float(input("Enter your speed amount : "))

if speed_limit > 80:
  print("You need to pay ! ")
else:
  print("Your speed is ok :" , speed_limit)
# Out:
# Enter your speed amount : yo
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3629601169.py in <cell line: 0>()
# ----> 1 speed_limit = float(input("Enter your speed amount : "))
#       2
#       3 if speed_limit > 80:
#       4   print("You need to pay ! ")
#       5 else:
#
# ValueError: could not convert string to float: 'yo'

# %%
temperature = float(input("Enter your temperature amount : "))

if temperature > 30:
  print("Alert sysytem need to cool down ! ")
else:
  print("Sysytem status is normal " : , temperature)
# Out:
#   File "/tmp/ipython-input-56130382.py", line 6
#     print("Sysytem status is normal " : , temperature)
#                                       ^
# SyntaxError: invalid syntax

# %%
order_amount = float(input("Enter your order amount : "))

if order_amount > 100:
  print("You got free shpipping ! ")
else:
  print("You have to pay a 10 usd for shipping :" , order_amount)
# Out:
# Enter your order amount : 70
# You have to pay a 10 usd for shipping : 70.0

# %%
ticket_reciever = float(input("Enter your age : "))

if ticket_reciever > 65:

 if ticket_reciever < 18:
  print("You got free shpipping ! ")
else:
  print("You have to pay a 10 usd for shipping :" , order_amount)
# Out:
#   File "/tmp/ipython-input-2804029364.py", line 4
#     if ticket_reciever < 18:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
ticket_reciever = float(input("Enter your age : "))

if ticket_reciever > 65:
  print("You got free shpipping ! ")
else:
  print("You have to pay a 10 usd for shipping :" , order_amount)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3163689599.py in <cell line: 0>()
# ----> 1 ticket_reciever = float(input("Enter your age : "))
#       2
#       3 if ticket_reciever > 65:
#       4   print("You got free shpipping ! ")
#       5 else:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
ticket_reciever = float(input("Enter your age : "))

if ticket_reciever < 18 or ticket_reciever > 65:
  print("You got a 50% discount ! ")
else:
  print("You have to pay full price :" , order_amount)
# Out:
# Enter your age : 45
# You have to pay full price : 70.0
